# %% [markdown]
# # Importing Data from DBeaver

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
cnx = create_engine('postgresql://ubuntu@3.22.99.1:5432/project_3')

# %%
df = pd.read_sql_query('''SELECT * FROM dataframe''', cnx)

# %%
df.head(3)
# Out:
#    countyfips     county_name    state  population  ppl_popdensity  \
# 0        1001  Autauga County  Alabama       55869           91.80
# 1        1003  Baldwin County  Alabama      223234          114.65
# 2        1005  Barbour County  Alabama       24686           31.03
#
#    county_beds  total_cases  total_deaths  days_since_case1  \
# 0          173           30             1                29
# 1          692          123             2                39
# 2           76           28             0                19
#
#    days_since_death1  county_hospitalizations  county_testing_rate  \
# 0                 14                 0.344198             0.017450
# 1                  4                 0.353185             0.004367
# 2                  0                 0.727052             0.039492
#
#    cases_wk_before  deaths_wk_before  pcnt_inc_wk10  pcnt_inc_wk11  \
# 0                7                 0       0.714286       0.916667
# ...

# %%
df.at_risk.describe()
# Out:
# count    3141.000000
# mean        0.044890
# std         0.207096
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: at_risk, dtype: float64

# %%
df.to_csv('proj3_data.csv')
